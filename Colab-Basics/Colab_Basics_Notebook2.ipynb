# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubh-sadekar/Colab-Notebooks/blob/master/Colab-Basics/Colab_Basics_Notebook2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colab Basics 2**
# This colab notebook will help you understand some of the simple things you can do in google colab. These can come handy while doing larger projects.
#
# #### This notebook will cover the following topics :
# 1. Installing some of the dependencies needed for performing DL and CV related projects.
# 2. Importing/colning a `GitHub repository.`
# 3. Use the data from the cloned repository.

# %% [markdown]
# ## **Installing** some of the dependencies needed for performing DL and CV related projects

# %%
# !apt-get install python-numpy python-scipy
# !pip3 install opencv-python

# %% [markdown]
# NOTE : For above lines we are not running any python command. They are terminal command with which we are installing the dependencies. Note that the `**“!”**` exclamation mark in the commands above is what is known as a `**“shell magic command”**` and allows us to make calls to the underlying Colaboratory virtual machine.
#
# In present version of colab notebooks OpenCV is pre-installed. Main purpose of the above code block is to show how to run linux commands.

# %% [markdown]
# ## Cloning a GitHub repository

# %%
# !git clone https://github.com/kaustubh-sadekar/DataFolder.git
# Out:
# Cloning into 'DataFolder'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
# Present directory
# !echo printing present dirrectory
# !pwd
# We observe that we are enterring simple linux terminal commands with a ! sign.
# Out:
# printing present dirrectory
# /content

# %%
# !echo Files inside DataFolder ....
# !ls '/content/DataFolder/'

# !echo Files inside colab-images folder ....
# !ls '/content/DataFolder/colab-images/'
# Out:
# Files inside DataFolder ....
# colab-images  LICENSE  README.md
# Files inside colab-images folder ....
# minions1.jpg  minions2.jpeg  mountains.jpeg

# %% [markdown]
# The above section explains how you can clone a repository (in this case it is https://github.com/kaustubh-sadekar/DataFolder.git).
# We see how we can access files in the DataFolder using `/content/DataFolder/`

# %% [markdown]
# ## Reading an image form cloned repository using OpenCV and displaying using matplotlib
#
# You can create a different folder in google drive where you store your images and videos for experiments.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import cv2

#Absolute path of the image saved in cloned folder.
path = "/content/DataFolder/colab-images/minions1.jpg"
img = cv2.imread(path)
plt.imshow(img)
plt.show()

# %% [markdown]
# #### Something is wrong with the above image!!!!
# `OMG ! the minions looks scarry !!`
# This is because `opencv uses BGR` format while storing the image after reading it where as other than opencv the format used is RGB thus we need to convert the color channesl of the image from BGR to RGB.

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)   # That's the magical line !!!!!
plt.imshow(img)
plt.show()
